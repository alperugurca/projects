# %% [markdown]
# ## DL Ann ###
# Derin Öğrenme Yapay Sinir Ağı

# %% [markdown]
# ## Kütüphaneleri Yükle ##

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /opt/conda/lib/python3.10/site-packages (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from tensorflow) (21.3)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from tensorflow) (69.0.3)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (4.9.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (0.35.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (1.59.3)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (2.15.1)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.26.1)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.5.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->tensorflow) (3.1.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /opt/conda/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.15.0'

# %%
#Kütüphaneleri içe aktar ve versiyoınları kontrol et
import pandas as pd
print ('Pandas vs:', pd.__version__)

import numpy as np
print ('Numpy vs:', np.__version__)

import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Pandas vs: 2.2.2
# Numpy vs: 1.26.4

# %%
pip show matplotlib
# Out:
# Name: matplotlib
# Version: 3.7.5
# Summary: Python plotting package
# Home-page: https://matplotlib.org
# Author: John D. Hunter, Michael Droettboom
# Author-email: matplotlib-users@python.org
# License: PSF
# Location: /opt/conda/lib/python3.10/site-packages
# Requires: contourpy, cycler, fonttools, kiwisolver, numpy, packaging, pillow, pyparsing, python-dateutil
# Required-by: arviz, beatrix_jupyterlab, Cartopy, catboost, cleverhans, contextily, descartes, explainable-ai-sdk, fastai, fitter, geoplot, ggplot, hypertools, imgaug, ipympl, ipyvolume, lime, matplotlib-venn, missingno, mlxtend, mne, mpld3, phik, plotnine, pointpats, prophet, PyUpSet, scikit-plot, seaborn, segregation, splot, stable-baselines3, vaex-viz, vtk, wfdb, wordcloud, ydata-profiling, yellowbrick
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Veri Setini İçe Aktar ##

# %%
df=pd.read_csv('/kaggle/input/pima-indias-diabet/pima-indians-diabetes.csv')

# %% [markdown]
# ## EDA ##

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# pie plot
df['Outcome'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Outcome'].value_counts().plot(kind='pie', autopct='%1.1f%%', shadow=True)
# Out:
# <Axes: ylabel='count'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
len(df[df['BMI']<5])
# Out:
# 11

# %%
df_reg=df[df['BMI']>=5]

# %%
df_reg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 757 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               757 non-null    int64
#  1   Glucose                   757 non-null    int64
#  2   BloodPressure             757 non-null    int64
#  3   SkinThickness             757 non-null    int64
#  4   Insulin                   757 non-null    int64
#  5   BMI                       757 non-null    float64
#  6   DiabetesPedigreeFunction  757 non-null    float64
#  7   Age                       757 non-null    int64
#  8   Outcome                   757 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 59.1 KB

# %% [markdown]
# ## Özellikleri ve Hedefi Seç ##

# %%
y=df_reg['Outcome']
X=df_reg.drop('Outcome',axis=1)

# %%
X
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   32
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# 763                     0.171   63
# 764                     0.340   27
# 765                     0.245   30
# 766                     0.349   47
# 767                     0.315   23
#
# [757 rows x 8 columns]

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 757, dtype: int64

# %% [markdown]
# ## Standarlaştırma & Normalleştirme ##

# %%
from sklearn.preprocessing  import StandardScaler
sc=StandardScaler()
#sc.fit(X)
#X=sc.transform(X)
X=sc.fit_transform(X)

# %% [markdown]
# ## Modeli Oluştur ##

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model=Sequential()
model.add(Dense(120, activation='relu'))
model.add(Dense (64,activation='relu'))
model.add(Dense (6, activation='relu'))
model.add(Dense (1,activation='sigmoid'))
model.compile (loss='binary_crossentropy', 
               optimizer='adam',
               metrics=['accuracy','Precision','Recall'],
              )

# %%
history=model.fit(X,y,
                 epochs=50,
                 batch_size=32,
                 validation_split=0.2,
                 verbose=1,
                 )
# Out:
# Epoch 1/50
# 19/19 [==============================] - 2s 18ms/step - loss: 0.6112 - accuracy: 0.7207 - precision: 0.6483 - recall: 0.4434 - val_loss: 0.5581 - val_accuracy: 0.7434 - val_precision: 0.7273 - val_recall: 0.4444
# Epoch 2/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.5090 - accuracy: 0.7620 - precision: 0.7125 - recall: 0.5377 - val_loss: 0.4914 - val_accuracy: 0.7632 - val_precision: 0.7143 - val_recall: 0.5556
# Epoch 3/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4644 - accuracy: 0.7868 - precision: 0.7371 - recall: 0.6085 - val_loss: 0.4658 - val_accuracy: 0.7566 - val_precision: 0.6977 - val_recall: 0.5556
# Epoch 4/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4550 - accuracy: 0.7884 - precision: 0.7414 - recall: 0.6085 - val_loss: 0.4629 - val_accuracy: 0.7632 - val_precision: 0.7250 - val_recall: 0.5370
# Epoch 5/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.4410 - accuracy: 0.7917 - precision: 0.7363 - recall: 0.6321 - val_loss: 0.4655 - val_accuracy: 0.7632 - val_precision: 0.7143 - val_recall: 0.5556
# Epoch 6/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4405 - accuracy: 0.7868 - precision: 0.7196 - recall: 0.6415 - val_loss: 0.4661 - val_accuracy: 0.7697 - val_precision: 0.7568 - val_recall: 0.5185
# Epoch 7/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4275 - accuracy: 0.7950 - precision: 0.7558 - recall: 0.6132 - val_loss: 0.4559 - val_accuracy: 0.7566 - val_precision: 0.6809 - val_recall: 0.5926
# Epoch 8/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4258 - accuracy: 0.7851 - precision: 0.7030 - recall: 0.6698 - val_loss: 0.4694 - val_accuracy: 0.7697 - val_precision: 0.7568 - val_recall: 0.5185
# Epoch 9/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4201 - accuracy: 0.8000 - precision: 0.7826 - recall: 0.5943 - val_loss: 0.4542 - val_accuracy: 0.7697 - val_precision: 0.7021 - val_recall: 0.6111
# Epoch 10/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4141 - accuracy: 0.7967 - precision: 0.7259 - recall: 0.6745 - val_loss: 0.4628 - val_accuracy: 0.7895 - val_precision: 0.7750 - val_recall: 0.5741
# Epoch 11/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4106 - accuracy: 0.8116 - precision: 0.7784 - recall: 0.6462 - val_loss: 0.4519 - val_accuracy: 0.7697 - val_precision: 0.7021 - val_recall: 0.6111
# Epoch 12/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4093 - accuracy: 0.8050 - precision: 0.7701 - recall: 0.6321 - val_loss: 0.4513 - val_accuracy: 0.7632 - val_precision: 0.6957 - val_recall: 0.5926
# Epoch 13/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4052 - accuracy: 0.8033 - precision: 0.7435 - recall: 0.6698 - val_loss: 0.4664 - val_accuracy: 0.7895 - val_precision: 0.7895 - val_recall: 0.5556
# Epoch 14/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.3954 - accuracy: 0.8083 - precision: 0.7759 - recall: 0.6368 - val_loss: 0.4501 - val_accuracy: 0.8026 - val_precision: 0.7500 - val_recall: 0.6667
# Epoch 15/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3905 - accuracy: 0.8165 - precision: 0.7644 - recall: 0.6887 - val_loss: 0.4538 - val_accuracy: 0.7895 - val_precision: 0.7750 - val_recall: 0.5741
# Epoch 16/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3970 - accuracy: 0.8083 - precision: 0.7697 - recall: 0.6462 - val_loss: 0.4578 - val_accuracy: 0.8092 - val_precision: 0.7660 - val_recall: 0.6667
# Epoch 17/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3861 - accuracy: 0.8198 - precision: 0.7977 - recall: 0.6509 - val_loss: 0.4521 - val_accuracy: 0.7895 - val_precision: 0.7391 - val_recall: 0.6296
# Epoch 18/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.3797 - accuracy: 0.8149 - precision: 0.7632 - recall: 0.6840 - val_loss: 0.4727 - val_accuracy: 0.7697 - val_precision: 0.7568 - val_recall: 0.5185
# Epoch 19/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3803 - accuracy: 0.8231 - precision: 0.8107 - recall: 0.6462 - val_loss: 0.4592 - val_accuracy: 0.7961 - val_precision: 0.7556 - val_recall: 0.6296
# Epoch 20/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3705 - accuracy: 0.8298 - precision: 0.7978 - recall: 0.6887 - val_loss: 0.4605 - val_accuracy: 0.7961 - val_precision: 0.7674 - val_recall: 0.6111
# Epoch 21/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3691 - accuracy: 0
50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2764 - accuracy: 0.8942 - precision: 0.8776 - recall: 0.8113 - val_loss: 0.5047 - val_accuracy: 0.7961 - val_precision: 0.7170 - val_recall: 0.7037
# Epoch 40/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2687 - accuracy: 0.8876 - precision: 0.8564 - recall: 0.8160 - val_loss: 0.5072 - val_accuracy: 0.8092 - val_precision: 0.7551 - val_recall: 0.6852
# Epoch 41/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.2706 - accuracy: 0.8959 - precision: 0.8901 - recall: 0.8019 - val_loss: 0.5159 - val_accuracy: 0.8092 - val_precision: 0.7551 - val_recall: 0.6852
# Epoch 42/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2596 - accuracy: 0.8959 - precision: 0.8706 - recall: 0.8255 - val_loss: 0.5327 - val_accuracy: 0.8092 - val_precision: 0.7451 - val_recall: 0.7037
# Epoch 43/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2483 - accuracy: 0.8992 - precision: 0.8832 - recall: 0.8208 - val_loss: 0.5280 - val_accuracy: 0.8158 - val_precision: 0.7600 - val_recall: 0.7037
# Epoch 44/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2407 - accuracy: 0.9025 - precision: 0.8696 - recall: 0.8491 - val_loss: 0.5285 - val_accuracy: 0.7895 - val_precision: 0.7391 - val_recall: 0.6296
# Epoch 45/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.2410 - accuracy: 0.9091 - precision: 0.9110 - recall: 0.8208 - val_loss: 0.5939 - val_accuracy: 0.7895 - val_precision: 0.7619 - val_recall: 0.5926
# Epoch 46/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.2341 - accuracy: 0.9124 - precision: 0.8916 - recall: 0.8538 - val_loss: 0.5308 - val_accuracy: 0.7961 - val_precision: 0.7170 - val_recall: 0.7037
# Epoch 47/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2323 - accuracy: 0.9124 - precision: 0.8995 - recall: 0.8443 - val_loss: 0.6098 - val_accuracy: 0.7632 - val_precision: 0.7250 - val_recall: 0.5370
# Epoch 48/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.2251 - accuracy: 0.9174 - precision: 0.9175 - recall: 0.8396 - val_loss: 0.5550 - val_accuracy: 0.8092 - val_precision: 0.7660 - val_recall: 0.6667
# Epoch 49/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.2222 - accuracy: 0.9140 - precision: 0.9082 - recall: 0.8396 - val_loss: 0.5540 - val_accuracy: 0.8092 - val_precision: 0.7358 - val_recall: 0.7222
# Epoch 50/50
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2137 - accuracy: 0.9190 - precision: 0.9137 - recall: 0.8491 - val_loss: 0.5709 - val_accuracy: 0.7961 - val_precision: 0.7347 - val_recall: 0.6667

# %% [markdown]
# history = model.fit(X, y, ...): Bu satır, verilen eğitim verileri X ve hedef değişkenler y kullanılarak modelin eğitim sürecini başlatıyor. Eğitim işlemi sonunda, eğitim süreci hakkında ayrıntılı bilgileri içeren bir history objesi döndürülüyor.
# epochs=50: Bu parametre, eğitim sürecinin toplam 50 adım (epoch) boyunca devam edeceğini belirtiyor. Yani model, eğitim verileriyle 50 kez işlem yapacak.
# batch_size=32: Eğitim sırasında, modele 32 adet örnek (veri) verilecek ve ardından ağırlıklar güncellenecek. Batch boyutu, eğitim etkinliği ve bellek kullanımı açısından önemli bir parametredir.
# validation_split=0.2: Bu parametre, eğitim verileri içinden %20'lik bir kısmının doğrulama (validation) verileri olarak ayrılacağını belirtiyor. Doğrulama verileri, modelin eğitim sırasındaki performansını ölçmek için kullanılır.
# verbose=1: Bu parametre, eğitim süreci hakkında ayrıntılı bilgilerin konsola yazdırılacağını gösteriyor. verbose=0 olsaydı, eğitim sürecine dair güncellemeler gösterilmeyecekti.

# %% [markdown]
# ''' iyi değil'''
# #2 nd Model
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
#
# model = Sequential()
# model.add(Dense(128, activation='relu', input_shape=(X.shape[1],)))
# model.add(BatchNormalization())
# model.add(Dropout(0.3))
#
# model.add(Dense(64, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dropout(0.3))
#
# model.add(Dense(32, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dropout(0.3))
#
# model.add(Dense(1, activation='sigmoid'))
#
# model.compile(loss='binary_crossentropy',
#               optimizer='adam',
#               metrics=['accuracy', 'Precision', 'Recall'])

# %% [markdown]
# from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
# history = model.fit(X, y,
#                    epochs=100,
#                    batch_size=64,
#                    validation_split=0.2,
#                    callbacks=[
#                        EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True),
#                        ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5)
#                    ],
#                    verbose=1)

# %%
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_29 (Dense)            (None, 120)               1080
#
#  dense_30 (Dense)            (None, 64)                7744
#
#  dense_31 (Dense)            (None, 6)                 390
#
#  dense_32 (Dense)            (None, 1)                 7
#
# =================================================================
# Total params: 9221 (36.02 KB)
# Trainable params: 9221 (36.02 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
plt.plot(history.history['accuracy'], label='Tr Accuracy')
plt.plot(history.history['val_accuracy'], label='ValAccuracy')
plt.legend()

# %% [markdown]
# ## Modeli Kaydet ##

# %%
model.save('diabetes.h5')

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %% [markdown]
# ## NB Deploy ##

# %%
def predict_diabetes(input_data):
    input_data=np.asarray(input_data)
    input_data=input_data.reshape(1,-1)
    input_data=sc.transform(input_data)
    prediction=model.predict(input_data)
    print('Tahmin Olasılığı:', prediction[0])
    if prediction[0]>.5:
        return 1
    else: return 0

# %% [markdown]
# input_data.reshape(1,-1) kodu, input_data adlı bir veri kümesini yeniden şekillendirmektedir. Burada:
#
# 1: Yeni şeklin ilk boyutunun 1 olduğunu belirtir. Yani, tek bir örnek (satır) olacak.
# -1: İkinci boyutun değerinin otomatik olarak hesaplanacağını belirtir. Bu, veri kümesinin orijinal boyutuna bağlı olarak belirlenecektir.
# Sonuç olarak, bu kod satırı, input_data adlı veri kümesini tek örnek (satır) içeren bir tensöre (numpy dizisine) dönüştürmektedir. Bu, örneğin, tek bir örnek üzerinde tahmin yapmak istediğinizde kullanışlı olabilir. İşlem sonucunda, input_data artık tek bir satır ve orijinal sütun sayısına sahip bir tensör olacaktır.

# %% [markdown]
# * Değerleri girin hamilelik sayısı: 8
# * Değerleri girin glikoz değeri: 183
# * Değerleri girin kan basıncı: 64
# * Değerleri girin deri kalınlığı: 0
# * Değerleri girin insulin: 0
# * Değerleri girin vücut kitle indeksi: 23.3
# * Değerleri girin diyabet soy fonksiyonu: 0.672
# * Değerleri girin yaş: 32

# %%
input_data=[]
columns=['Hamilelik sayısı', 'Glikoz değeri', 'Kan Basıncı',
        'Deri Kalınlığı', 'İnsulin', 'Vct Kitle İnd', "Diyabet Soy Fonks", 'Yaş']

for column in columns:
    value=float(input('Değerleri girin ' + column +": "))
    input_data.append(value)

    #Make Predictions
prediction = predict_diabetes(input_data)
print(prediction)
# Out:
# Değerleri girin Hamilelik sayısı:  8
# Değerleri girin Glikoz değeri:  183
# Değerleri girin Kan Basıncı:  64
# Değerleri girin Deri Kalınlığı:  0
# Değerleri girin İnsulin:  0
# Değerleri girin Vct Kitle İnd:  23.3
# Değerleri girin Diyabet Soy Fonks:  .672
# Değerleri girin Yaş:  32
# 1/1 [==============================] - 0s 97ms/step
# Tahmin Olasılığı: [0.95009625]
# 1

# %%
if prediction==1:
    print('Diyabet pozitif')
else:
    print('Diyabet negatif')
# Out:
# Diyabet pozitif
