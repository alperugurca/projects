# %%
#!pip3 install imageio

# %%
import imageio.v3 as iio
from PIL import Image

filenames = ['r3.jpg', 'r2.jpg', 'r1.jpg'] # File names
images = []

first_image = Image.open(filenames[0])
width, height = first_image.size

for filename in filenames:
  img = Image.open(filename)
  img = img.resize((width, height))
  images.append(img)

iio.imwrite('rabbit.gif', images, duration = 500, loop = 0) # Settings

# %%
from IPython.display import Image, display

display(Image(url='https://i.imgur.com/KU6oUhC.gif'))
# Out:
# <img src="https://i.imgur.com/KU6oUhC.gif"/>
